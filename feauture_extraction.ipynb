# %% [markdown]
# # FEATURE IMPORTANCE

# %%
import shap

# Finding index of class 1 sample
class1_indices = np.where(y_test == 1)[0]
sample_index = class1_indices[0]  # pick first one

# Extract the row and compute SHAP values for it
X_sample = X_test[sample_index:sample_index+1]  # keep 2D shape
explainer = shap.Explainer(final_model)
shap_values_sample = explainer(X_sample)

# Display the force plot
shap.initjs()
shap.force_plot(
    shap_values_sample.base_values[0],
    shap_values_sample.values[0],
    feature_names=shap_values_sample.feature_names,
    matplotlib=True
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
#SHAP
feature_names = df5[top_100].columns.tolist()
# Convert test set to DataFrame for SHAP
X_test_df = pd.DataFrame(X_test, columns=feature_names)

# Compute SHAP values
explainer = shap.Explainer(final_model)
shap_values = explainer(X_test_df)

# === SHAP Summary Plot (Global) ===
shap.summary_plot(shap_values, X_test_df)

# %%
import shap
import pandas as pd
import numpy as np

# 1. converting X_test to a DataFrame with feature names
X_test_df = pd.DataFrame(X_test, columns=feature_names)

# 2. Get class 1 indices from y_test
class1_indices = np.where(y_test == 1)[0]

# 3. Subset test data for class 1
X_test_class1_df = X_test_df.iloc[class1_indices]

# 4. Create SHAP explainer and compute SHAP values for class 1 data
explainer = shap.Explainer(final_model)
shap_values_class1 = explainer(X_test_class1_df)

# 5. Plot SHAP summary for class 1 predictions
shap.summary_plot(shap_values_class1, X_test_class1_df, max_display=30)
